# %% [markdown]
# # Python Basics - Tutorial Preparation

# %% [markdown]
# ## 1. Installing and Importing Libraries
#
# For data analysis in Python, you need to install and import necessary libraries.

# %%
# Installing libraries (run once only)
# pip install pandas numpy matplotlib

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Reading Data (CSV Files)
#
# Read CSV files and convert them into DataFrame objects.

# %%
# Creating sample data
data = {
    'x': [1, 2, 3, 4, 5],
    'y': [2, 4, 5, 4, 5]
}
df2 = pd.DataFrame(data)
df2
# Out:
#    x  y
# 0  1  2
# 1  2  4
# 2  3  5
# 3  4  4
# 4  5  5

# %%
# Reading CSV file (when you have an actual file)
# Out:
#    x  y
# 0  1  2
# 1  2  4
# 2  3  5
# 3  4  4
# 4  5  5

# %% [markdown]
# ## 3. Examining Data
#
# ### 3.1 Viewing Top Rows (.head())

# %%
# View first 5 rows
# Out:
#    x  y
# 0  1  2
# 1  2  4
# 2  3  5
# 3  4  4
# 4  5  5

# %% [markdown]
# ### 3.2 Checking Descriptive Statistics (.describe())

# %%
# Check mean, standard deviation, min, max, etc.
# Out:
#               x         y
# count  5.000000  5.000000
# mean   3.000000  4.000000
# std    1.581139  1.224745
# min    1.000000  2.000000
# 25%    2.000000  4.000000
# 50%    3.000000  4.000000
# 75%    4.000000  5.000000
# max    5.000000  5.000000

# %% [markdown]
# ## 4. Calculating Correlation (.corr())
#
# Measure the linear relationship between two variables.

# %%
# Complete correlation matrix
# Out:
# Complete correlation matrix:
#           x         y
# x  1.000000  0.774597
# y  0.774597  1.000000

# %% [markdown]
# ## 5. Loops (for loop)

# %% [markdown]
# ### 5.1 Looping with Dictionaries

# %%
# Example dictionary


# Loop through keys and values together
# Out:
# y1: 0.3
# y2: 0.4
# y3: 0.1

# %% [markdown]
# ## 6. Visualization (Matplotlib)
#
# ### 6.1 Basic Scatter Plot

# %%
# Simple scatter plot

# %% [markdown]
# ### 6.2 Subplots (Multiple Plots)

# %%
# Create 2x2 subplots

# %% [markdown]
# ### 6.3 Adding Linear Regression Line

# %%
# Linear regression using numpy
# Out:
# Regression equation: y = 0.60x + 2.20

# %% [markdown]
# ## 7. Calculating Statistics
#
# ### 7.1 Basic Statistics

# %%
# Mean
# Out:
# Mean of X: 3.00
# Mean of Y: 4.00
#
# Variance of X: 2.00
# Variance of Y: 1.20
#
# Standard deviation of X: 1.41
# Standard deviation of Y: 1.10

# %% [markdown]
# ## 8. String Formatting (f-strings)
#
# How to insert variables into strings in Python.

# %%
# Out:
# Language: Python
# Version: 3.9
# Score: 96
# 10 + 3 = 13
# 10 / 3 = 3.33
