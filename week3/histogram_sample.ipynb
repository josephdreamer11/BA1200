# %%
import numpy as np 
import matplotlib.pyplot as plt 

df = np.random.normal(size = 1000, loc = 50 , scale = 10)

plt.hist(df, bins = 30)
# Out:
# (array([ 1.,  1.,  7.,  7.,  8., 13., 21., 31., 30., 60., 63., 65., 73.,
#         72., 78., 78., 85., 83., 45., 55., 40., 31., 16., 14.,  9.,  5.,
#          3.,  1.,  4.,  1.]),
#  array([18.32722063, 20.51571234, 22.70420405, 24.89269576, 27.08118747,
#         29.26967918, 31.45817089, 33.6466626 , 35.83515431, 38.02364601,
#         40.21213772, 42.40062943, 44.58912114, 46.77761285, 48.96610456,
#         51.15459627, 53.34308798, 55.53157969, 57.7200714 , 59.90856311,
#         62.09705482, 64.28554653, 66.47403824, 68.66252994, 70.85102165,
#         73.03951336, 75.22800507, 77.41649678, 79.60498849, 81.7934802 ,
#         83.98197191]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(df, bins = 10)
# Out:
# (array([  9.,  28.,  82., 188., 223., 246., 140.,  61.,  17.,   6.]),
#  array([18.32722063, 24.89269576, 31.45817089, 38.02364601, 44.58912114,
#         51.15459627, 57.7200714 , 64.28554653, 70.85102165, 77.41649678,
#         83.98197191]),
#  <BarContainer object of 10 artists>)
